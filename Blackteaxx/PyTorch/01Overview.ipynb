# %% [markdown]
# >>>
# 1. Requirements:
#     1.  Linear Algebra/ Probability
# 2. Goal:
#     1. ```How to implement learning system using PyTorch```
#     2. ```Understand the basics concepts of neural networks```
# ***
# >>>
# - Differences in Algorithm:
#     - Algorithm in Lessons:
#         - 穷举法
#         - 贪心法
#         - 分治法
#         - 动态规划
#     - Algorithm in Machine Learning
#         - From Dataset
# ***
# - Rule-Based System
# - Traditional Machine Learning Strategy
#  ![image.png](attachment:image.png)
# - Represent
